# %%
import pandas as pd

# %%
Billing_Invoice_Fact=pd.read_csv(r"D:\RCM\Billing_Invoice_Fact.csv")

# %%
Claim_Processing_Fact=pd.read_csv(r"D:\RCM\Claim_Processing_Fact.csv")

# %%
Cost_Center_Master=pd.read_csv(r"D:\RCM\Cost_Center_Master.csv")

# %%
Date_Dimension=pd.read_csv(r"D:\RCM\Date_Dimension.csv")

# %%
Department_Master=pd.read_csv(r"D:\RCM\Department_Master.csv")

# %%
Employee_Master=pd.read_csv(r"D:\RCM\Employee_Master.csv")

# %%
Finance_Fact=pd.read_csv(r"D:\RCM\Finance_Fact.csv")

# %%
GL_Account_Master=pd.read_csv(r"D:\RCM\GL_Account_Master.csv")

# %%
Insurance_Master=pd.read_csv(r"D:\RCM\Insurance_Master.csv")

# %%
Patient_Encounter_Fact=pd.read_csv(r"D:\RCM\Patient_Encounter_Fact.csv")

# %%
Patient_Master=pd.read_csv(r"D:\RCM\Patient_Master.csv")

# %%
Payer_Master=pd.read_csv(r"D:\RCM\Payer_Master.csv")

# %%
Payment_AR_Fact=pd.read_csv(r"D:\RCM\Payment_AR_Fact.csv")

# %%
Procedure_Master=pd.read_csv(r"D:\RCM\Procedure_Master.csv")

# %%
Productivity_Performance_Fact=pd.read_csv(r"D:\RCM\Productivity_Performance_Fact.csv")

# %%
Provider_Master=pd.read_csv(r"D:\RCM\Provider_Master.csv")

# %%
Reference_Master=pd.read_csv(r"D:\RCM\Reference_Master.csv")

# %%
Region_Master=pd.read_csv(r"D:\RCM\Region_Master.csv")

# %%
Transaction_Identity_Fact=pd.read_csv(r"D:\RCM\Transaction_Identity_Fact.csv")

# %%
Validation_Fact=pd.read_csv(r"D:\RCM\Validation_Fact.csv")

# %%
Vendor_Master=pd.read_csv(r"D:\RCM\Vendor_Master.csv")

# %%
tables={"Billing_Invoice_Fact":Billing_Invoice_Fact,
        "Claim_Processing_Fact":Claim_Processing_Fact,
        "Cost_Center_Master":Cost_Center_Master,
        "Date_Dimension":Date_Dimension,
        "Department_Master":Department_Master,
        "Employee_Master":Employee_Master,
        "Finance_Fact":Finance_Fact,
        "GL_Account_Master":GL_Account_Master,
        "Insurance_Master":Insurance_Master,
        "Patient_Encounter_Fact":Patient_Encounter_Fact,
        "Patient_Master":Patient_Master,
        "Payer_Master":Payer_Master,
        "Payment_AR_Fact":Payment_AR_Fact,
        "Procedure_Master":Procedure_Master,
        "Productivity_Performance_Fact":Productivity_Performance_Fact,
        "Provider_Master":Provider_Master,
        "Reference_Master":Reference_Master,
        "Region_Master":Region_Master,
        "Transaction_Identity_Fact":Transaction_Identity_Fact,
        "Validation_Fact":Validation_Fact,
        "Vendor_Master":Vendor_Master}

# %%
len(tables)
# Out:
# 21

# %%
tables.keys()
# Out:
# dict_keys(['Billing_Invoice_Fact', 'Claim_Processing_Fact', 'Cost_Center_Master', 'Date_Dimension', 'Department_Master', 'Employee_Master', 'Finance_Fact', 'GL_Account_Master', 'Insurance_Master', 'Patient_Encounter_Fact', 'Patient_Master', 'Payer_Master', 'Payment_AR_Fact', 'Procedure_Master', 'Productivity_Performance_Fact', 'Provider_Master', 'Reference_Master', 'Region_Master', 'Transaction_Identity_Fact', 'Validation_Fact', 'Vendor_Master'])
